# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay23-54c2/python/blob/main/rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data mimicking R's VADeaths dataset
data = {
    'Age Group': ['50-54', '55-59', '60-64', '65-69', '70-74'],
    'Rural Male': [11.7, 18.1, 26.9, 41.0, 66.0],
    'Rural Female': [8.7, 11.7, 20.3, 30.9, 54.3],
    'Urban Male': [15.4, 24.3, 37.0, 54.6, 71.1],
    'Urban Female': [8.4, 13.6, 19.3, 35.1, 50.0]
}
df = pd.DataFrame(data)

# Melt the data for easier histogram plotting
df_melted = pd.melt(df, id_vars='Age Group', var_name='Group', value_name='Death Rate')

# Basic histogram using matplotlib
plt.figure(figsize=(10, 6))
plt.hist(df_melted['Death Rate'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Death Rates in Virginia')
plt.xlabel('Death Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram by group using seaborn
plt.figure(figsize=(10, 6))
sns.histplot(df_melted, x='Death Rate', hue='Group', bins=10, kde=True, palette='muted')
plt.title('Death Rates by Group')
plt.show()

# Grouped histogram using pandas
df_melted.groupby('Group')['Death Rate'].plot(kind='hist', alpha=0.5, legend=True, bins=10)
plt.title('Grouped Histogram of Death Rates')
plt.xlabel('Death Rate')
plt.show()
